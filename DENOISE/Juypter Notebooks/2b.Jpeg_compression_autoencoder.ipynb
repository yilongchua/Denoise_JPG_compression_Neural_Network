# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %matplotlib inline
import math
import keras
from keras import backend as K
import numpy as np
import os
import matplotlib.pylab as plt

# %% [markdown]
# **Create necessary directories**

# %%
P_MODELSAVE = '/content/drive/MyDrive/modeling_tsk2_3/saved_models'
P_LOGS = '/content/drive/MyDrive/modeling_tsk2_3/logs'
P_IMGSAVE = '/content/drive/MyDrive/modeling_tsk2_3/saved_images'
dirs = [P_MODELSAVE, P_LOGS, P_IMGSAVE]

for d in dirs:
    if not os.path.exists(d):
        os.makedirs(d)
        
saved_weight = P_MODELSAVE+ '/dataweights{epoch:02d}.hdf5'
saved_weight

# %% [markdown]
# DataFrame directory

# %%
import glob
import pandas as pd
drive_path = '/content/drive/MyDrive/AIDNS_AssignmentData/images/Clean/clean_images'
clean_images = list(glob.glob(drive_path + '/*.jpg'))
drive_path = '/content/drive/MyDrive/AIDNS_AssignmentData/images/jpeg_compress/train'
noisy_images = list(glob.glob(drive_path + '/*.jpg'))
df_clean = pd.DataFrame(clean_images, columns=['clean'])
df_noise = pd.DataFrame(noisy_images, columns=['noise'])
df_clean['num'] = df_clean['clean'].apply(lambda x: int(x.split('_')[-1].split('.')[0]))
df_noise['num'] = df_noise['noise'].apply(lambda x: int(x.split('_')[-1].split('.')[0]))
train = pd.merge(df_clean, df_noise, on='num', how = 'outer')
train.sort_values('num', inplace = True)
train.reset_index(drop=True, inplace = True)
print(train.isnull().sum().sum())
train
# Out:
# 0
#                                                   clean  ...                                              noise
# 0     /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 1     /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 2     /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 3     /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 4     /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# ...                                                 ...  ...                                                ...
# 1223  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 1224  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 1225  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 1226  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 1227  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
#
# [1228 rows x 3 columns]

# %%
import glob
import pandas as pd
drive_path = '/content/drive/MyDrive/AIDNS_AssignmentData/images/val/val images'
clean_images = list(glob.glob(drive_path + '/*.jpg'))
drive_path = '/content/drive/MyDrive/AIDNS_AssignmentData/images/jpeg_compress/val'
noisy_images = list(glob.glob(drive_path + '/*.jpg'))
df_clean = pd.DataFrame(clean_images, columns=['clean'])
df_noise = pd.DataFrame(noisy_images, columns=['noise'])
df_clean['num'] = df_clean['clean'].apply(lambda x: int(x.split('_')[-1].split('.')[0]))
df_noise['num'] = df_noise['noise'].apply(lambda x: int(x.split('_')[-1].split('.')[0]))
valid = pd.merge(df_clean, df_noise, on='num', how = 'outer')
valid.sort_values('num', inplace = True)
valid.reset_index(drop=True, inplace = True)
print(valid.isnull().sum().sum())
valid
# Out:
# 0
#                                                  clean  ...                                              noise
# 0    /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 1    /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 2    /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 3    /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 4    /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# ..                                                 ...  ...                                                ...
# 520  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 521  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 522  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 523  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 524  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
#
# [525 rows x 3 columns]

# %%
valid
# Out:
#                                                  clean  ...                                              noise
# 0    /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 1    /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 2    /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 3    /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 4    /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# ..                                                 ...  ...                                                ...
# 520  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 521  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 522  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 523  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
# 524  /content/drive/MyDrive/AIDNS_AssignmentData/im...  ...  /content/drive/MyDrive/AIDNS_AssignmentData/im...
#
# [525 rows x 3 columns]

# %% [markdown]
# **Image Data Generator**

# %%
from keras.preprocessing.image import ImageDataGenerator

size = (256,256)
batch_size = 16
train_steps = math.ceil(train.shape[0]/ batch_size)
valid_steps = math.ceil(valid.shape[0]/ batch_size)

data_gen_args = dict(rescale=1./255)

data_flow_args = dict (
    labels        = None,
    target_size   = size,
    color_mode    = 'rgb',
    class_mode    = None,
    batch_size    = batch_size,
    shuffle       = False,
    # seed          = 27,
    save_format   = 'jpg',
    interpolation = "bicubic", 
    validate_filenames = True)

# %%
noise_train_generator = ImageDataGenerator(**data_gen_args).flow_from_dataframe(
    dataframe     = train,
    x_col         = 'noise',
    **data_flow_args)

clean_train_generator = ImageDataGenerator(**data_gen_args).flow_from_dataframe(
    dataframe     = train,
    x_col         = 'clean',
    **data_flow_args)

noise_valid_generator = ImageDataGenerator(**data_gen_args).flow_from_dataframe(
    dataframe     = valid,
    x_col         = 'noise',
    **data_flow_args)
clean_valid_generator = ImageDataGenerator(**data_gen_args).flow_from_dataframe(
    dataframe     = valid,
    x_col         = 'clean',
    **data_flow_args)

train_generator = (pair for pair in zip(noise_train_generator,clean_train_generator))
valid_generator = (pair for pair in zip(noise_valid_generator,clean_valid_generator))
# Out:
# Found 1228 validated image filenames.
# Found 1228 validated image filenames.
# Found 525 validated image filenames.
# Found 525 validated image filenames.

# %%
i = 10
batch = 0
noise_img =(noise_valid_generator[batch][i]*255).astype(int)
plt.imshow(noise_img)
plt.show()


clean_img =(clean_valid_generator[batch][i]*255).astype(int)
plt.imshow(clean_img)
plt.show()

# %% [markdown]
# ## Model

# %%
import keras.layers as layers
import keras.models as models
from keras.initializers import orthogonal
import tensorflow as tf

def Conv2DLayer(x, filters, kernel, strides, padding, block_id, kernel_init=orthogonal()):
    prefix = f'block_{block_id}_'
    x = layers.Conv2D(filters, kernel_size=kernel, strides=strides, padding=padding,
                      kernel_initializer=kernel_init, name=prefix+'conv')(x)
    x = layers.LeakyReLU(name=prefix+'lrelu')(x)
    x = layers.Dropout(0.2, name=prefix+'drop')((x))
    x = layers.BatchNormalization(name=prefix+'conv_bn')(x)
    return x

def Transpose_Conv2D(x, filters, kernel, strides, padding, block_id, kernel_init=orthogonal()):
    prefix = f'block_{block_id}_'
    x = layers.Conv2DTranspose(filters, kernel_size=kernel, strides=strides, padding=padding,
                               kernel_initializer=kernel_init, name=prefix+'de-conv')(x)
    x = layers.LeakyReLU(name=prefix+'lrelu')(x)
    x = layers.Dropout(0.2, name=prefix+'drop')((x))
    x = layers.BatchNormalization(name=prefix+'conv_bn')(x)
    return x



def AutoEncdoer(input_shape):
    inputs = layers.Input(shape=input_shape)
    
    # 256 x 256
    conv1 = Conv2DLayer(inputs, 64, 3, strides=1, padding='same', block_id=1)
    conv2 = Conv2DLayer(conv1, 64, 3, strides=2, padding='same', block_id=2)
    
    # 128 x 128
    conv3 = Conv2DLayer(conv2, 128, 5, strides=2, padding='same', block_id=3)
    
    # 64 x 64
    conv4 = Conv2DLayer(conv3, 128, 3, strides=1, padding='same', block_id=4)
    conv5 = Conv2DLayer(conv4, 256, 5, strides=2, padding='same', block_id=5)
    
    # 32 x 32
    conv6 = Conv2DLayer(conv5, 512, 3, strides=2, padding='same', block_id=6)
    
    # 16 x 16
    deconv1 = Transpose_Conv2D(conv6, 512, 3, strides=2, padding='same', block_id=7)
    
    # 32 x 32
    skip1 = layers.concatenate([deconv1, conv5], name='skip1')
    conv7 = Conv2DLayer(skip1, 256, 3, strides=1, padding='same', block_id=8)
    deconv2 = Transpose_Conv2D(conv7, 128, 3, strides=2, padding='same', block_id=9)
    
    # 64 x 64
    skip2 = layers.concatenate([deconv2, conv3], name='skip2')
    conv8 = Conv2DLayer(skip2, 128, 5, strides=1, padding='same', block_id=10)
    deconv3 = Transpose_Conv2D(conv8, 64, 3, strides=2, padding='same', block_id=11)
    
    # 128 x 128
    skip3 = layers.concatenate([deconv3, conv2], name='skip3')
    conv9 = Conv2DLayer(skip3, 64, 5, strides=1, padding='same', block_id=12)
    deconv4 = Transpose_Conv2D(conv9, 64, 3, strides=2, padding='same', block_id=13)
    
    # 256 x 256
    skip3 = layers.concatenate([deconv4, conv1])
    conv10 = layers.Conv2D(3, 3, strides=1, padding='same', activation='sigmoid',
                       kernel_initializer=orthogonal(), name='final_conv')(skip3)

    
    return models.Model(inputs=inputs, outputs=conv10)

# %% [markdown]
# **Build and compile the model**

# %%
from keras.optimizers import  Adam
model = AutoEncdoer((*size, 3))
model_opt = Adam(learning_rate=0.0002)

model.compile(optimizer=model_opt, loss='mse', metrics=['mse'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# block_1_conv (Conv2D)           (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block_1_lrelu (LeakyReLU)       (None, 256, 256, 64) 0           block_1_conv[0][0]
# __________________________________________________________________________________________________
# block_1_drop (Dropout)          (None, 256, 256, 64) 0           block_1_lrelu[0][0]
# __________________________________________________________________________________________________
# block_1_conv_bn (BatchNormaliza (None, 256, 256, 64) 256         block_1_drop[0][0]
# __________________________________________________________________________________________________
# block_2_conv (Conv2D)           (None, 128, 128, 64) 36928       block_1_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_2_lrelu (LeakyReLU)       (None, 128, 128, 64) 0           block_2_conv[0][0]
# __________________________________________________________________________________________________
# block_2_drop (Dropout)          (None, 128, 128, 64) 0           block_2_lrelu[0][0]
# __________________________________________________________________________________________________
# block_2_conv_bn (BatchNormaliza (None, 128, 128, 64) 256         block_2_drop[0][0]
# __________________________________________________________________________________________________
# block_3_conv (Conv2D)           (None, 64, 64, 128)  204928      block_2_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_3_lrelu (LeakyReLU)       (None, 64, 64, 128)  0           block_3_conv[0][0]
# __________________________________________________________________________________________________
# block_3_drop (Dropout)          (None, 64, 64, 128)  0           block_3_lrelu[0][0]
# __________________________________________________________________________________________________
# block_3_conv_bn (BatchNormaliza (None, 64, 64, 128)  512         block_3_drop[0][0]
# __________________________________________________________________________________________________
# block_4_conv (Conv2D)           (None, 64, 64, 128)  147584      block_3_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_4_lrelu (LeakyReLU)       (None, 64, 64, 128)  0           block_4_conv[0][0]
# __________________________________________________________________________________________________
# block_4_drop (Dropout)          (None, 64, 64, 128)  0           block_4_lrelu[0][0]
# __________________________________________________________________________________________________
# block_4_conv_bn (BatchNormaliza (None, 64, 64, 128)  512         block_4_drop[0][0]
# __________________________________________________________________________________________________
# block_5_conv (Conv2D)           (None, 32, 32, 256)  819456      block_4_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_5_lrelu (LeakyReLU)       (None, 32, 32, 256)  0           block_5_conv[0][0]
# __________________________________________________________________________________________________
# block_5_drop (Dropout)          (None, 32, 32, 256)  0           block_5_lrelu[0][0]
# __________________________________________________________________________________________________
# block_5_conv_bn (BatchNormaliza (None, 32, 32, 256)  1024        block_5_drop[0][0]
# __________________________________________________________________________________________________
# block_6_conv (Conv2D)           (None, 16, 16, 512)  1180160     block_5_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_6_lrelu (LeakyReLU)       (None, 16, 16, 512)  0           block_6_conv[0][0]
# __________________________________________________________________________________________________
# block_6_drop (Dropout)          (None, 16, 16, 512)  0           block_6_lrelu[0][0]
# __________________________________________________________________________________________________
# block_6_conv_bn (BatchNormaliza (None, 16, 16, 512)  2048        block_6_drop[0][0]
# __________________________________________________________________________________________________
# block_7_de-conv (Conv2DTranspos (None, 32, 32, 512)  2359808     block_6_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_7_lrelu (LeakyReLU)       (None, 32, 32, 512)  0           block_7_de-conv[0][0]
# __________________________________________________________________________________________________
# block_7_drop (Dropout)          (None, 32, 32, 512)  0           block_7_lrelu[0][0]
# __________________________________________________________________________________________________
# block_7_conv_bn (BatchNormaliza (None, 32, 32, 512)  2048        block_7_drop[0][0]
# __________________________________________________________________________________________________
# skip1 (Concatenate)             (None, 32, 32, 768)  0           block_7_conv_bn[0][0]
#                                                                  block_5_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_8_conv (Conv2D)           (None, 32, 32, 256)  1769728     skip1[0][0]
# __________________________________________________________________________________________________
# block_8_lrelu (LeakyReLU)       (None, 32, 32, 256)  0           block_8_conv[0][0]
# __________________________________________________________________________________________________
# block_8_drop (Dropout)          (None, 32, 32, 256)  0           block_8_lrelu[0][0]
# __________________________________________________________________________________________________
# block_8_conv_bn (BatchNormaliza (None, 32, 32, 256)  1024        block_8_drop[0][0]
# __________________________________________________________________________________________________
# block_9_de-conv (Conv2DTranspos (None, 64, 64, 128)  295040      block_8_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_9_lrelu (LeakyReLU)       (None, 64, 64, 128)  0           block_9_de-conv[0][0]
# __________________________________________________________________________________________________
# block_9_drop (Dropout)          (None, 64, 64, 128)  0           block_9_lrelu[0][0]
# __________________________________________________________________________________________________
# block_9_conv_bn (BatchNormaliza (None, 64, 64, 128)  512         block_9_drop[0][0]
# __________________________________________________________________________________________________
# skip2 (Concatenate)             (None, 64, 64, 256)  0           block_9_conv_bn[0][0]
#                                                                  block_3_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_10_conv (Conv2D)          (None, 64, 64, 128)  819328      skip2[0][0]
# __________________________________________________________________________________________________
# block_10_lrelu (LeakyReLU)      (None, 64, 64, 128)  0           block_10_conv[0][0]
# __________________________________________________________________________________________________
# block_10_drop (Dropout)         (None, 64, 64, 128)  0           block_10_lrelu[0][0]
# __________________________________________________________________________________________________
# block_10_conv_bn (BatchNormaliz (None, 64, 64, 128)  512         block_10_drop[0][0]
# __________________________________________________________________________________________________
# block_11_de-conv (Conv2DTranspo (None, 128, 128, 64) 73792       block_10_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_11_lrelu (LeakyReLU)      (None, 128, 128, 64) 0           block_11_de-conv[0][0]
# __________________________________________________________________________________________________
# block_11_drop (Dropout)         (None, 128, 128, 64) 0           block_11_lrelu[0][0]
# __________________________________________________________________________________________________
# block_11_conv_bn (BatchNormaliz (None, 128, 128, 64) 256         block_11_drop[0][0]
# __________________________________________________________________________________________________
# skip3 (Concatenate)             (None, 128, 128, 128 0           block_11_conv_bn[0][0]
#                                                                  block_2_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_12_conv (Conv2D)          (None, 128, 128, 64) 204864      skip3[0][0]
# __________________________________________________________________________________________________
# block_12_lrelu (LeakyReLU)      (None, 128, 128, 64) 0           block_12_conv[0][0]
# __________________________________________________________________________________________________
# block_12_drop (Dropout)         (None, 128, 128, 64) 0           block_12_lrelu[0][0]
# __________________________________________________________________________________________________
# block_12_conv_bn (BatchNormaliz (None, 128, 128, 64) 256         block_12_drop[0][0]
# __________________________________________________________________________________________________
# block_13_de-conv (Conv2DTranspo (None, 256, 256, 64) 36928       block_12_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_13_lrelu (LeakyReLU)      (None, 256, 256, 64) 0           block_13_de-conv[0][0]
# __________________________________________________________________________________________________
# block_13_drop (Dropout)         (None, 256, 256, 64) 0           block_13_lrelu[0][0]
# __________________________________________________________________________________________________
# block_13_conv_bn (BatchNormaliz (None, 256, 256, 64) 256         block_13_drop[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 256, 256, 128 0           block_13_conv_bn[0][0]
#                                                                  block_1_conv_bn[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 256, 256, 3)  3459        concatenate[0][0]
# ==================================================================================================
# Total params: 7,963,267
# Trainable params: 7,958,531
# Non-trainable params: 4,736
# __________________________________________________________________________________________________

# %% [markdown]
# **Some useful callbacks**

# %%
modelchk = keras.callbacks.ModelCheckpoint(saved_weight, 
                                      monitor='val_mse', 
                                      verbose=1,
                                      save_best_only=True, 
                                      save_weights_only=False,
                                      mode='auto',
                                      period=3)

tensorboard = keras.callbacks.TensorBoard(log_dir=P_LOGS,
                                          histogram_freq=0,
                                          write_graph=True,
                                          write_images=True)

csv_logger = keras.callbacks.CSVLogger(f'{P_LOGS}/keras_log.csv',
                                       append=True)

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=3,
                              verbose=1,
                              min_delta=0.0001)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
model.fit(train_generator,
          steps_per_epoch = train_steps,
          epochs=150,
          verbose=1, 
          validation_data=valid_generator,
          validation_steps = valid_steps,
          callbacks=[modelchk, tensorboard, csv_logger],
          
          )
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1276s 17s/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 2/150
# 77/77 [==============================] - 543s 7s/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 3/150
# 77/77 [==============================] - 538s 7s/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0045 - val_mse: 0.0045
#
# Epoch 00003: val_mse improved from inf to 0.00451, saving model to /content/drive/MyDrive/AIDNS_AssignmentData/modeling_tsk2_2/saved_models/dataweights03.hdf5
# Epoch 4/150
# 77/77 [==============================] - 536s 7s/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 5/150
# 77/77 [==============================] - 532s 7s/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 6/150
# 77/77 [==============================] - 524s 7s/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0047 - val_mse: 0.0047
#
# Epoch 00006: val_mse did not improve from 0.00451
# Epoch 7/150
# 77/77 [==============================] - 530s 7s/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0226 - val_mse: 0.0226
# Epoch 8/150
# 77/77 [==============================] - 531s 7s/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 9/150
# 77/77 [==============================] - 530s 7s/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0052 - val_mse: 0.0052
#
# Epoch 00009: val_mse did not improve from 0.00451
# Epoch 10/150
# 77/77 [==============================] - 527s 7s/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 11/150
# 77/77 [==============================] - 530s 7s/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 12/150
# 77/77 [==============================] - 523s 7s/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0044 - val_mse: 0.0044
#
# Epoch 00012: val_mse improved from 0.00451 to 0.00441, saving model to /content/drive/MyDrive/AIDNS_AssignmentData/modeling_tsk2_2/saved_models/dataweights12.hdf5
# Epoch 13/150
# 77/77 [==============================] - 523s 7s/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 14/150
# 77/77 [==============================] - 523s 7s/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 15/150
# 77/77 [==============================] - 525s 7s/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0041 - val_mse: 0.0041
#
# Epoch 00015: val_mse improved from 0.00441 to 0.00411, saving model to /content/drive/MyDrive/AIDNS_AssignmentData/modeling_tsk2_2/saved_models/dataweights15.hdf5
# Epoch 16/150
# 77/77 [==============================] - 523s 7s/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 17/150
# 77/77 [==============================] - 523s 7s/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 18/150
# 77/77 [==============================] - 521s 7s/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0043 - val_mse: 0.0043
#
# Epoch 00018: val_mse did not improve from 0.00411
# Epoch 19/150
# 77/77 [==============================] - 520s 7s/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 20/150
# 77/77 [==============================] - 520s 7s/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 21/150
# 77/77 [==============================] - 521s 7s/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0055 - val_mse: 0.0055
#
# Epoch 00021: val_mse did not improve from 0.00411
# Epoch 22/150
# 77/77 [==============================] - 519s 7s/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 23/150
# 77/77 [==============================] - 523s 7s/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 24/150
# 77/77 [==============================] - 520s 7s/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0129 - val_mse: 0.0129
#
# Epoch 00024: val_mse did not improve from 0.00411
# Epoch 25/150
# 77/77 [==============================] - 520s 7s/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 26/150
# 77/77 [==============================] - 522s 7s/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 27/150
# 77/77 [==============================] - 522s 7s/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0054 - val_mse: 0.0054
#
# Epoch 00027: val_mse did not improve from 0.00411
# Epoch 28/150
# 77/77 [==============================] - 522s 7s/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 29/150
# 77/77 [==============================] - 522s 7s/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 30/150
# 77/77 [==============================] - 517s 7s/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0057 - val_mse: 0.0057
#
# Epoch 00030: val_mse did not improve from 0.00411
# Epoch 31/150
# 77/77 [==============================] - 520s 7s/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 32/150
# 77/77 [==============================] - 522s 7s/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 33/150
# 77/77 [==============================] - 522s 7s/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0061 - val_mse: 0.0061
#
# Epoch 00033: val_mse did not improve from 0.00411
# Epoch 34/150
# 77/77 [==============================] - 525s 7s/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 35/150
# 77/77 [==============================] - 522s 7s/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 36/150
# 77/77 [==============================] - 521s 7s/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0075 - val_mse: 0.0075
#
# Epoch 00036: val_mse did not improve from 0.00411
# Epoch 37/150
# 77/77 [==============================] - 521s 7s/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 38/150
# 77/77 [==============================] - 523s 7s/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 39/150
# 77/77 [==============================] - 520s 7s/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0039 - val_mse: 0.0039
#
# Epoch 00039: val_mse improved from 0.00411 to 0.00387, saving model to /content/drive/MyDrive/AIDNS_AssignmentData/modeling_tsk2_2/saved_models/dataweights39.hdf5
# Epoch 40/150
# 77/77 [==============================] - 521s 7s/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 41/150
# 77/77 [==============================] - 519s 7s/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 42/150
# 77/77 [==============================] - 520s 7s/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0046 - val_mse: 0.0046
#
# Epoch 00042: val_mse did not improve from 0.00387
# Epoch 43/150
# 77/77 [==============================] - 519s 7s/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 44/150
# 77/77 [==============================] - 521s 7s/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 45/150
# 77/77 [==============================] - 514s 7s/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0037 - val_mse: 0.0037
#
# Epoch 00045: val_mse improved from 0.00387 to 0.00373, saving model to /content/drive/MyDrive/AIDNS_AssignmentData/modeling_tsk2_2/saved_models/dataweights45.hdf5
# Epoch 46/150
# 77/77 [==============================] - 520s 7s/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 47/150
# 77/77 [==============================] - 519s 7s/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 48/150
# 77/77 [==============================] - 520s 7s/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0051 - val_mse: 0.0051
#
# Epoch 00048: val_mse did not improve from 0.00373
# Epoch 49/150
# 77/77 [==============================] - 519s 7s/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 50/150
# 77/77 [==============================] - 518s 7s/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 51/150
# 77/77 [==============================] - 518s 7s/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0037 - val_mse: 0.0037
#
# Epoch 00051: val_mse did not improve from 0.00373
# Epoch 52/150
# 77/77 [==============================] - 518s 7s/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 53/150
# 77/77 [==============================] - 518s 7s/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 54/150
# 77/77 [==============================] - 518s 7s/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0037 - val_mse: 0.0037
#
# Epoch 00054: val_mse did not improve from 0.00373
# Epoch 55/150
# 77/77 [==============================] - 517s 7s/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 56/150
# 77/77 [==============================] - 519s 7s/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 57/150
# 77/77 [==============================] - 517s 7s/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0034 - val_mse: 0.0034
#
# Epoch 00057: val_mse improved from 0.00373 to 0.00341, saving model to /content/drive/MyDrive/AIDNS_AssignmentData/modeling_tsk2_2/saved_models/dataweights57.hdf5
# Epoch 58/150
# 77/77 [==============================] - 518s 7s/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 59/150
# 77/77 [==============================] - 517s 7s/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 60/150
# 77/77 [==============================] - 517s 7s/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0041 - val_mse: 0.0041
#
# Epoch 00060: val_mse did not improve from 0.00341
# Epoch 61/150
# 77/77 [==============================] - 517s 7s/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 62/150
# 77/77 [==============================] - 520s 7s/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 63/150
# 77/77 [==============================] - 520s 7s/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0036 - val_mse: 0.0036
#
# Epoch 00063: val_mse did not improve from 0.00341
# Epoch 64/150
# 77/77 [==============================] - 517s 7s/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 65/150
# 77/77 [==============================] - 518s 7s/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 66/150
# 77/77 [==============================] - 515s 7s/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0037 - val_mse: 0.0037
#
# Epoch 00066: val_mse did not improve from 0.00341
# Epoch 67/150
# 77/77 [==============================] - 517s 7s/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 68/150
# 77/77 [==============================] - 519s 7s/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 69/150
# 77/77 [==============================] - 518s 7s/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0033 - val_mse: 0.0033
#
# Epoch 00069: val_mse improved from 0.00341 to 0.00334, saving model to /content/drive/MyDrive/AIDNS_AssignmentData/modeling_tsk2_2/saved_models/dataweights69.hdf5
# Epoch 70/150
# 77/77 [==============================] - 518s 7s/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 71/150
# 77/77 [==============================] - 517s 7s/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 72/150
# 77/77 [==============================] - 517s 7s/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0035 - val_mse: 0.0035
#
# Epoch 00072: val_mse did not improve from 0.00334
# Epoch 73/150
# 77/77 [==============================] - 517s 7s/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 74/150
# 77/77 [==============================] - 526s 7s/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 75/150
# 77/77 [==============================] - 522s 7s/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0034 - val_mse: 0.0034
#
# Epoch 00075: val_mse did not improve from 0.00334
# Epoch 76/150
# 77/77 [==============================] - 521s 7s/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 77/150
# 77/77 [==============================] - 514s 7s/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 78/150
# 77/77 [==============================] - 521s 7s/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0033 - val_mse: 0.0033
#
# Epoch 00078: val_mse improved from 0.00334 to 0.00326, saving model to /content/drive/MyDrive/AIDNS_AssignmentData/modeling_tsk2_2/saved_models/dataweights78.hdf5
# Epoch 79/150
# 77/77 [==============================] - 514s 7s/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 80/150
# 42/77 [===============>..............] - ETA: 3:31 - loss: 0.0055 - mse: 0.0055

# %%
model.save('/content/drive/MyDrive/modeling_tsk2_3/saved_models/AE_task2_1.hdf5')

# %%
# model_ae = keras.models.load_model('/content/drive/MyDrive/AIDNS_AssignmentData/modeling_tsk2/saved_models_2/dataweights02.hdf5')
model_ae = keras.models.load_model('/content/drive/MyDrive/AIDNS_AssignmentData/modeling_tsk2_2/saved_models/dataweights78.hdf5')

# %%
score = model.evaluate(valid_generator)
print('Test loss:', score[0])
print('Test MSE:', score[1])

# %%
import matplotlib.pyplot as plt

n = 5

plt.figure(figsize=(40, 15))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(noise_valid_generator[0][i])
    ax.axis('off')

    ax = plt.subplot(2, n, i + n + 1)
    plt.imshow(decoded_imgs[i])
    ax.axis('off')

plt.show()

# %%
from math import log10, sqrt
import cv2
num = 9
GT_path_1 = f'/content/drive/MyDrive/AIDNS_AssignmentData/GroundTruth/GT_0{num}.png'
T_path_1 = f'/content/drive/MyDrive/AIDNS_AssignmentData/TASK1/Task1_0{num}.png'

def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    if(mse == 0): # MSE is zero means no noise is present in the signal .
                  # Therefore PSNR have no importance.
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr
  

def model_compare_image_resize(org_path, new_path, model, i_size = (256,256)):
    original = cv2.imread(org_path)
    compressed_org = cv2.imread(new_path, 1).astype(np.float32)
    compressed = cv2.resize(compressed_org, i_size, interpolation= cv2.INTER_AREA)
    compressed /= 255.0
    compressed = compressed.reshape([1] + list(compressed.shape))
    decoded_img = model.predict(compressed)[0]
    decoded_img *= 255.0
    decoded_imgs = cv2.resize(decoded_img, (original.shape[1], original.shape[0]), interpolation= cv2.INTER_AREA)
    decoded_imgs = decoded_imgs.astype(int)


    value_predict = PSNR(original, decoded_imgs)
    value_non_predict = PSNR(original, compressed_org)
    print(f"PSNR value is model predict : {value_predict} dB")
    print(f"PSNR value is w/o model : {value_non_predict} dB")

    return value_predict, value_non_predict
       

model_compare_image_resize(GT_path_1, T_path_1, model)
# Out:
# PSNR value is model predict : 3.527783502865848 dB
# PSNR value is w/o model : 21.50442490975683 dB
# (3.527783502865848, 21.50442490975683)
